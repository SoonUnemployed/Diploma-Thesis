# %%
import pandas as pd
from pathlib import Path

# %%
path = Path("/Users/hrakol/projects/diploma_thesis/data/processed/split.csv")

df1= pd.read_csv(path)

# %%
df = df1.drop(columns = ["user"])
print(df[df["split"] == "test"])
# Out:
#               session split
# 3   user_18_session_3  test
# 4   user_18_session_2  test
# 17  user_11_session_3  test
# 23  user_12_session_1  test
# 33  user_07_session_1  test
# 35  user_07_session_3  test
# 36  user_14_session_2  test
# 40  user_07_session_2  test
